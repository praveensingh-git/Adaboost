# %%
import pandas as pd

data = [
    [7,7,1],[4,5,0],[5,6,1],[3,4,1],[6,6,1],
    [2,3,0],[8,8,1],[4,4,0],[7,6,1],[5,5,0],
    [6,7,1],[3,5,0],[9,9,1],[1,2,0],[8,7,1],
    [4,6,0],[7,8,1],[2,4,0],[6,5,1],[3,3,0],
    [7,7,1],[5,4,0],[8,9,1],[2,2,0],[6,6,1],
    [4,3,0],[9,8,1],[1,3,0],[7,6,1],[5,5,0],
    [8,8,1],[3,4,0],[6,7,1],[2,3,0],[7,9,1],
    [4,5,0],[9,9,1],[1,2,0],[8,7,1],[3,5,0],
    [6,8,1],[2,4,0],[7,7,1],[5,6,0],[8,9,1],
    [3,2,0],[6,6,1],[4,4,0],[9,8,1],[2,1,0]
]

df = pd.DataFrame(data, columns=["X1", "X2", "label"])

print(df.head())
